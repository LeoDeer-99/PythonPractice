# %% [markdown]
# # IMDB Score Predictor
# In this notebook, I built an IMDB movie score predictor and generally analyzed the ratings and what kind of biases and preferences the film ratings have. I am using a data set from this GitHub: https://github.com/danielgrijalva/movie-stats which scrapes film ratings from IMDB between X and Y years.
#
# #### Table of Contents
# 1) Data Cleaning and Processing
# 2) Data Visualizations
# 3) Data Exploration - SQL
# 4) Model
# 5) Conclusions
#
# #### Revision History
# * Last revised 13-May-2023 by Leo Deer (leo99deer@gmail.com).

# %% [markdown]
# ### Importing Packages and defining functions for later

# %%
# %load_ext sql
# %sql sqlite:///RealWorldData.db

import csv, sqlite3, random, ssl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math


from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn import preprocessing
from sklearn import utils
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn import svm
from sklearn.svm import SVR
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix, accuracy_score
import sklearn.metrics as metrics
from sklearn.metrics import r2_score

con = sqlite3.connect("RealWorldData.db")
cur = con.cursor

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## 1. Data Cleaning and Processing

# %%
df_movie = pd.read_csv("moviesDB2.csv")
df_movie.dropna(inplace = True)

# %%
df_movie.genre.unique()
# Out:
# array(['Drama', 'Adventure', 'Action', 'Comedy', 'Horror', 'Biography',
#        'Crime', 'Fantasy', 'Animation', 'Family', 'Western', 'Sci-Fi',
#        'Romance', 'Thriller', 'Mystery'], dtype=object)

# %% [markdown]
# A few of these genres only have a few films in the database. Very small in comparison to the actual size of the data set. So I will drop them.

# %%
df_movie = df_movie[df_movie['genre']!='Western']
df_movie = df_movie[df_movie['genre']!='Thriller']
df_movie = df_movie[df_movie['genre']!='Romance']
df_movie = df_movie[df_movie['genre']!='Sci-Fi']
df_movie = df_movie[df_movie['genre']!='Family']

# %%
df_movie.rating.unique()
# Out:
# array(['R', 'PG', 'G', 'NC-17', 'Approved', 'Not Rated', 'PG-13',
#        'Unrated', 'X', 'TV-MA'], dtype=object)

# %% [markdown]
# Same for ratings

# %%
df_movie = df_movie[df_movie['rating']!='X']
df_movie = df_movie[df_movie['rating']!='Approved']
df_movie = df_movie[df_movie['rating']!='TV-MA']

# %% [markdown]
# I want to change the 'Release' category to only include the release month

# %%
df_movie = df_movie.rename(columns={'released': 'Month'})
df_movie['Month'] = df_movie['Month'].str.split(' ').str[0]

# %%
df_movie.Month.unique()
# Out:
# array(['June', 'July', 'May', 'December', 'October', 'September',
#        'February', 'April', 'August', 'March', 'November', 'January',
#        '1982', '1985', '1995', '2019'], dtype=object)

# %%
df_movie = df_movie[df_movie['Month']!='1982']
df_movie = df_movie[df_movie['Month']!='1985']
df_movie = df_movie[df_movie['Month']!='1995']
df_movie = df_movie[df_movie['Month']!='2019']

# %%
df_movie = df_movie.set_index(np.arange(0, df_movie.shape[0], dtype=int))
df_movie
# Out:
#                                                 name     rating      genre
# 0                                        The Shining          R      Drama  \
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5384                               Bad Boys for Life          R     Action
# 5385                              Sonic the Hedgehog         PG     Action
# 5386                                        Dolittle         PG  Adventure
# 5387                            The Call of the Wild         PG  Adventure
# 5388                               The Eight Hundred  Not Rated     Action
#
#       year     Month  score      votes         director
# 0     1980      June    8.4   927000.0  Stanley Kubrick  \
# 1     1980      July    5.8    65000.0   Randal Kleiser
# 2     1980      June    8.7  1200000.0   Irvin Kershner
# 3     1980      July    7.7   221000.0     Jim Abrahams
# 4     1980      July    7.3   108000.0     Harold Ramis
# ...    ...       ...    ...        ...              ...
# 5384  2020   January    6.6   140000.0     Adil El Arbi
# 5385  2020  February    6.5   102000.0      Jeff Fowler
# 5386  2020   January    5.6    53000.0   Stephen Gaghan
# 5387  2020  February    6.8    42000.0    Chris Sanders
# 5388  2020    August    6.8     3700.0          Hu Guan
#
#                        writer               star         country       budget
# 0                Stephen King     Jack Nicholson  United Kingdom   19000000.0  \
# 1     Henry De Vere Stacpoole     Brooke Shields   United States    4500000.0
# 2              Leigh Brackett        Mark Hamill   United States   18000000.0
# 3                Jim Abrahams        Robert Hays   United States    3500000.0
# 4          Brian Doyle-Murray        Chevy Chase   United States    6000000.0
# ...                       ...                ...             ...          ...
# 5384              Peter Craig         Will Smith   United States   90000000.0
# 5385                Pat Casey       Ben Schwartz   United States   85000000.0
# 5386           Stephen Gaghan  Robert Downey Jr.   United States  175000000.0
# 5387            Michael Green      Harrison Ford          Canada  135000000.0
# 5388                  Hu Guan    Zhi-zhong Huang           China   80000000.0
#
#             gross                              company  runtime
# 0      46998772.0                         Warner Bros.    146.0
# 1      58853106.0                    Columbia Pictures    104.0
# 2     538375067.0                            Lucasfilm    124.0
# 3      83453539.0                   Paramount Pictures     88.0
# 4      39846344.0                       Orion Pictures     98.0
# ...           ...                                  ...      ...
# 5384  426505244.0                    Columbia Pictures    124.0
# 5385  319715683.0                   Paramount Pictures     99.0
# 5386  245487753.0                   Universal Pictures    101.0
# 5387  111105497.0                 20th Century Studios    100.0
# 5388  461421559.0  Beijing Diqi Yinxiang Entertainment    149.0
#
# [5389 rows x 15 columns]

# %% [markdown]
# This is good for analysis and visualization, but these categorical variables need to be numerical to train a model. So, I'll make a second dataset, $\verb"df_train"$, to train our model with.

# %%
df_train = pd.concat([df_movie.loc[:,'name'], pd.get_dummies(df_movie.rating, dtype=int), pd.get_dummies(df_movie.genre, dtype=int), df_movie.loc[:,'year':]], ignore_index=False, sort=False, axis=1)

# %%
Calender = {"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, "July":7, "August":8, "September":9, "October":10, "November":11, "December":12}

for month in Calender:
    df_train['Month'] = df_train['Month'].replace(month, Calender[month])

# %%
df_train.country = pd.Categorical(df_movie.country)
df_train['Country Codes'] = df_train.country.cat.codes

# %%
df_train = df_train.drop(columns=['company', 'country', 'star', 'writer', 'director'], axis=1)
df_train
# Out:
#                                                 name  G  NC-17  Not Rated  PG
# 0                                        The Shining  0      0          0   0  \
# 1                                    The Blue Lagoon  0      0          0   0
# 2     Star Wars: Episode V - The Empire Strikes Back  0      0          0   1
# 3                                          Airplane!  0      0          0   1
# 4                                         Caddyshack  0      0          0   0
# ...                                              ... ..    ...        ...  ..
# 5384                               Bad Boys for Life  0      0          0   0
# 5385                              Sonic the Hedgehog  0      0          0   1
# 5386                                        Dolittle  0      0          0   1
# 5387                            The Call of the Wild  0      0          0   1
# 5388                               The Eight Hundred  0      0          1   0
#
#       PG-13  R  Unrated  Action  Adventure  ...  Horror  Mystery  year  Month
# 0         0  1        0       0          0  ...       0        0  1980      6  \
# 1         0  1        0       0          1  ...       0        0  1980      7
# 2         0  0        0       1          0  ...       0        0  1980      6
# 3         0  0        0       0          0  ...       0        0  1980      7
# 4         0  1        0       0          0  ...       0        0  1980      7
# ...     ... ..      ...     ...        ...  ...     ...      ...   ...    ...
# 5384      0  1        0       1          0  ...       0        0  2020      1
# 5385      0  0        0       1          0  ...       0        0  2020      2
# 5386      0  0        0       0          1  ...       0        0  2020      1
# 5387      0  0        0       0          1  ...       0        0  2020      2
# 5388      0  0        0       1          0  ...       0        0  2020      8
#
#       score      votes       budget        gross  runtime  Country Codes
# 0       8.4   927000.0   19000000.0   46998772.0    146.0             46
# 1       5.8    65000.0    4500000.0   58853106.0    104.0             47
# 2       8.7  1200000.0   18000000.0  538375067.0    124.0             47
# 3       7.7   221000.0    3500000.0   83453539.0     88.0             47
# 4       7.3   108000.0    6000000.0   39846344.0     98.0             47
# ...     ...        ...          ...          ...      ...            ...
# 5384    6.6   140000.0   90000000.0  426505244.0    124.0             47
# 5385    6.5   102000.0   85000000.0  319715683.0     99.0             47
# 5386    5.6    53000.0  175000000.0  245487753.0    101.0             47
# 5387    6.8    42000.0  135000000.0  111105497.0    100.0              6
# 5388    6.8     3700.0   80000000.0  461421559.0    149.0              8
#
# [5389 rows x 26 columns]

# %% [markdown]
# Now that we have out two data sets, we are going to do some analysis on them.

# %% [markdown]
# ## 2. Data Visualizations

# %% [markdown]
# Lets first create a couple plots that tell us more about the data we are working with.
#
# I want to see what kind of correlations there are with the film score to see what columns to keep for the regression.
#
# * 1 ) Distribution of Ratings
# * 2 ) Distribution of Ratings During a Given Period
# * 3a) Distribution of Release Year
# * 3b) Score Distribution by Year
# * 4a) Distribution of Release Month
# * 4b) Score Distribution by Month
# * 5a) Pie Chart of Genres
# * 5b) Distribution of Genres
# * 5c) Score Distribution by Genre
# * 6a) Distribution of Runtime
# * 6b) Score Distribution by Runtime
# * 7a) Score Distribution by Gross Profit
# * 7b) Score Distribution by Budget
# * 7c) Score Distribution by Gross Profit: Budget
# * 7d) Distribution of Gross Profit
# * 7e) Distribution of Budget
# * 7f) Distribution of Gross Profit: Budget
# * 8a) Distribution of Votes
# * 8b) Score Distribution by Votes

# %% [markdown]
# #### 1. Distribution of Ratings

# %%
max_score = 9.
min_score = 4.

score_std = np.std(df_movie['score'])
score_mean = np.mean(df_movie.loc[:,['score']])
film_total = df_movie.loc[:,['score']].shape[0]

# %%
films_per_rating = df_movie.loc[:,['score']].groupby('score').size()

bin_width = 0.1

gauss = (bin_width*film_total/np.sqrt(2*np.pi*score_std**2))*np.exp(-0.5*((np.arange(0,10.1,0.1)-score_mean)/score_std**2)**2)

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(3)

plt.bar(x = films_per_rating.keys(), height = films_per_rating, width=0.1)
plt.plot(np.arange(0,10.1,0.1), gauss, color = 'r')
plt.xticks(np.arange(0,10.1,0.5))
plt.yticks(np.arange(0,261,20))
plt.xlim(1.5,9.5)
plt.xlabel('Score')
plt.ylabel('# of Films')
plt.title('1. Distribution of Ratings')


plt.show()

# %% [raw]
# statistics on averages and std and then plot with gaussian

# %% [markdown]
# #### 2. Distribution of Ratings During a Given Period

# %%
min_year = 1980
max_year = 1981

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(3)

films_per_rating_range = df_movie.loc[(df_movie['year'] >= min_year) & (df_movie['year'] <= max_year),['score']].groupby('score').size()
plt.bar(x = films_per_rating_range.keys(), height = films_per_rating_range, width=0.1)
plt.xticks(np.arange(0,10.1,0.5))
plt.xlim(1.5,9.5)
plt.xlabel('Score')
plt.ylabel('# of Films')
plt.title('2. Distribution of Ratings Between '+str(min_year)+' & '+str(max_year))

plt.show()

# %% [markdown]
# #### 3a. Distribution of Release Year
# #### 3b. Score Distribution by Year

# %%
rating_by_year = df_movie.loc[:,['year','score']].groupby('year').mean()
films_per_year = df_movie.loc[:,['year']].groupby('year').size()

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(7)

plt.subplots_adjust(wspace=0.4, hspace=0.4)


ax = fig.add_subplot(2, 1, 1)
plt.bar(x = films_per_year.keys(), height = films_per_year, width = 1)
plt.xticks(np.arange(1980,2021,5))
plt.yticks(np.arange(0,176,25))
plt.xlim(1979.5,2020.5)
plt.xlabel('Year')
plt.ylabel('# of Films')
plt.title('3a. Distribution of Release Year')

ax = fig.add_subplot(2, 1, 2)
plt.plot(rating_by_year)
#plt.plot(score_mean)
plt.plot(films_per_year.keys(), np.full(len(films_per_year.keys()), score_mean), color='r')
plt.plot(films_per_year.keys(), np.full(len(films_per_year.keys()), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(films_per_year.keys(), np.full(len(films_per_year.keys()), score_mean+score_std), color='r', linestyle='dotted')
plt.xticks(np.arange(1980,2021,5))
plt.yticks(np.arange(min_score,max_score + 0.1,1))
plt.xlim(1979.5,2020.5)
plt.ylim(min_score,max_score)
plt.xlabel('Year')
plt.ylabel('IMDB Score')
plt.title('3b. Score Distribution by Year')

plt.show()

# %% [markdown]
# Its seems that there is almost no variation throughout time, so we will exclude this from out model

# %% [markdown]
# #### 4a. Distribution of Release Month
# #### 4b. Score Distribution by Month

# %%
rating_by_month = df_train.loc[:,['Month','score']].groupby('Month').mean()
films_per_month = df_train.loc[:,['Month']].groupby('Month').size()

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(7)

plt.subplots_adjust(wspace=0.4, hspace=0.4)


ax = fig.add_subplot(2, 1, 1)
plt.bar(x = films_per_month.keys(), height = films_per_month, width = 1)
plt.xticks(np.arange(1,13,1))
plt.yticks(np.arange(0,525,50))
plt.xlim(0.5,12.5)
plt.xlabel('Month')
plt.ylabel('# of Films')
plt.title('4a. Distribution of Release Month')


ax = fig.add_subplot(2, 1, 2)
plt.plot(rating_by_month)
plt.plot(films_per_month.keys(), np.full(len(films_per_month.keys()), score_mean), color='r')
plt.plot(films_per_month.keys(), np.full(len(films_per_month.keys()), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(films_per_month.keys(), np.full(len(films_per_month.keys()), score_mean+score_std), color='r', linestyle='dotted')
plt.xticks(np.arange(1,13,1))
plt.yticks(np.arange(min_score,max_score + 0.1,1))
plt.xlim(0.5,12.5)
plt.ylim(min_score,max_score)
plt.xlabel('Month')
plt.ylabel('IMDB Score')
plt.title('4b. Score Distribution by Month')


plt.show()

# %% [markdown]
# Likewise, this has almost no variation, and time of year seems rather irrelevant for how well a film will be rated

# %% [markdown]
# #### 5a. Pie Chart of Genres
# #### 5b. Distribution of Genres
# #### 5c. Score Distribution by Genre

# %%
rating_by_genre = df_movie.loc[:,['genre','score']].groupby('genre').mean()
films_per_genre = df_movie.loc[:,['genre']].groupby('genre').size()
percents_genre = films_per_genre * 100 / films_per_genre.sum()

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(9)

plt.subplots_adjust(wspace=0.4, hspace=0.4)


ax = fig.add_subplot(3, 1, 1)
films_per_genre.plot.pie(legend=True)
plt.legend(bbox_to_anchor=(2.2,1.1), loc='upper right', labels=['%s, %1.1f %%' % (l, s) for l, s in zip(percents_genre.keys(),percents_genre)])
plt.title('5a. Pie Chart of Genres')

ax = fig.add_subplot(3, 1, 2)
plt.bar(x = films_per_genre.keys(), height = films_per_genre, width = 1)
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('# of Films')
plt.title('5b. Distribution of Genres')

ax = fig.add_subplot(3, 1, 3)
plt.bar(x = rating_by_genre.index.tolist(), height = rating_by_genre['score'], width = 1)
plt.plot(rating_by_genre.index.tolist(), np.full(len(rating_by_genre.index.tolist()), score_mean), color='r')
plt.plot(rating_by_genre.index.tolist(), np.full(len(rating_by_genre.index.tolist()), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(rating_by_genre.index.tolist(), np.full(len(rating_by_genre.index.tolist()), score_mean+score_std), color='r', linestyle='dotted')
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.yticks(np.arange(min_score,max_score + 0.1,1))
plt.ylim(min_score,max_score)
plt.ylabel('IMDB Score')
plt.title('5c. Score Distribution by Genre')

plt.show()

# %% [markdown]
# There is some more significant variation in the genres so we will include this. But may change later.

# %%
rating_by_rating = df_movie.loc[:,['rating','score']].groupby('rating').mean()
films_per_rating = df_movie.loc[:,['rating']].groupby('rating').size()
percents_rating = films_per_rating * 100 / films_per_rating.sum()

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(9)

plt.subplots_adjust(wspace=0.4, hspace=0.8)


ax = fig.add_subplot(3, 1, 1)
films_per_genre.plot.pie(legend=True)
plt.legend(bbox_to_anchor=(2.2,1.1), loc='upper right', labels=['%s, %1.1f %%' % (l, s) for l, s in zip(percents_rating.keys(),percents_rating)])
plt.title('5a. Pie Chart of Ratings')

ax = fig.add_subplot(3, 1, 2)
plt.bar(x = films_per_rating.keys(), height = films_per_rating, width = 1)
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('# of Films')
plt.title('5b. Distribution of Ratings')

ax = fig.add_subplot(3, 1, 3)
plt.bar(x = rating_by_rating.index.tolist(), height = rating_by_rating['score'], width = 1)
plt.plot(rating_by_rating.index.tolist(), np.full(len(rating_by_rating.index.tolist()), score_mean), color='r')
plt.plot(rating_by_rating.index.tolist(), np.full(len(rating_by_rating.index.tolist()), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(rating_by_rating.index.tolist(), np.full(len(rating_by_rating.index.tolist()), score_mean+score_std), color='r', linestyle='dotted')
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.yticks(np.arange(min_score,max_score + 0.1,1))
plt.ylim(min_score,max_score)
plt.ylabel('IMDB Score')
plt.title('5c. Score Distribution by Ratings')

plt.show()

# %% [markdown]
# Very little variation, we wont include

# %%
rating_by_country = df_movie.loc[:,['country','score']].groupby('country').mean()
films_per_country = df_movie.loc[:,['country']].groupby('country').size()
percents_country = films_per_country * 100 / films_per_country.sum()

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(9)

plt.subplots_adjust(wspace=0.4, hspace=0.8)


ax = fig.add_subplot(2, 1, 1)
plt.bar(x = films_per_country.keys(), height = films_per_country, width = 1)
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('# of Films')
plt.title('5b. Distribution of Countries')

ax = fig.add_subplot(2, 1, 2)
plt.bar(x = rating_by_country.index.tolist(), height = rating_by_country['score'], width = 1)
plt.plot(rating_by_country.index.tolist(), np.full(len(rating_by_country.index.tolist()), score_mean), color='r')
plt.plot(rating_by_country.index.tolist(), np.full(len(rating_by_country.index.tolist()), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(rating_by_country.index.tolist(), np.full(len(rating_by_country.index.tolist()), score_mean+score_std), color='r', linestyle='dotted')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.yticks(np.arange(min_score,max_score + 0.1,1))
plt.ylim(min_score,max_score)
plt.ylabel('IMDB Score')
plt.title('5c. Score Distribution by Country')

plt.show()

# %% [markdown]
# We see that almost all the films are American, so we will only use American films in this model

# %% [markdown]
# #### 6a. Distribution of Runtime
# #### 6b. Score Distribution by Runtime

# %%
rating_by_runtime = df_movie.loc[:,['runtime','score']].groupby('runtime').mean()
films_per_runtime = df_train.loc[:,['runtime']].groupby('runtime').size()

fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(7)

plt.subplots_adjust(wspace=0.4, hspace=0.4)


ax = fig.add_subplot(2, 1, 1)
plt.bar(x = films_per_runtime.keys(), height = films_per_runtime, width = 1)
plt.xticks(np.arange(60,275,10))
plt.yticks(np.arange(0,176,25))
plt.xlim(60,275)
plt.xlabel('Run Time')
plt.ylabel('# of Films')
plt.title('6a. Distribution of Runtime')

ax = fig.add_subplot(2, 1, 2)
plt.plot(rating_by_runtime)
plt.plot(films_per_runtime.keys(), np.full(len(films_per_runtime.keys()), score_mean), color='r')
plt.plot(films_per_runtime.keys(), np.full(len(films_per_runtime.keys()), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(films_per_runtime.keys(), np.full(len(films_per_runtime.keys()), score_mean+score_std), color='r', linestyle='dotted')
plt.xticks(np.arange(60,275,10))
plt.yticks(np.arange(min_score,max_score + 0.1,1))
plt.xlim(60,275)
plt.ylim(min_score,max_score)
plt.xlabel('Run Time')
plt.ylabel('IMDB Score')
plt.title('6b. Score Distribution by Runtime')

plt.show()

# %% [markdown]
# This is significant

# %% [markdown]
# #### 7a. Score Distribution by Gross Profit
# #### 7b. Score Distribution by Budget
# #### 7c. Score Distribution by Gross Profit: Budget
# #### 7d. Distribution of Gross Profit
# #### 7e. Distribution of Budget
# #### 7f. Distribution of Gross Profit: Budget

# %%
smooth_factor = 10
bin_num = 100

# %%
df_movie['profit margin'] = df_movie['gross']/df_movie['budget']


rating_by_gross = df_movie.loc[:,['gross','score']].groupby('gross').mean().reset_index()
rating_by_gross = rating_by_gross.groupby(np.arange(len(rating_by_gross))//smooth_factor).mean()
rating_by_budget = df_movie.loc[:,['budget','score']].groupby('budget').mean().reset_index()
rating_by_budget = rating_by_budget.groupby(np.arange(len(rating_by_budget))//smooth_factor).mean()
rating_by_profitm = df_movie.loc[:,['profit margin','score']].groupby('profit margin').mean().reset_index()
rating_by_profitm = rating_by_profitm.groupby(np.arange(len(rating_by_profitm))//smooth_factor).mean()

films_per_gross = df_movie.loc[:,['gross']]
films_per_budget = df_movie.loc[:,['budget']]
films_per_profitm = df_movie.loc[:,['profit margin']]

logbins_gross = np.logspace(np.log10(films_per_gross['gross'].min()),np.log10(films_per_gross['gross'].max()),bin_num)
logbins_budget = np.logspace(np.log10(films_per_budget['budget'].min()),np.log10(films_per_budget['budget'].max()),bin_num)
logbins_profitm = np.logspace(np.log10(films_per_profitm['profit margin'].min()),np.log10(films_per_profitm['profit margin'].max()),bin_num)


fig = plt.figure()

fig.set_figwidth(12)
fig.set_figheight(12)

plt.subplots_adjust(wspace=0.3, hspace=0.4)

fig.suptitle('Genre Distribution', fontsize=16)


ax = fig.add_subplot(3, 2, 1)
plt.semilogx(rating_by_gross['gross'], rating_by_gross['score'])
plt.plot(rating_by_gross['gross'], np.full(len(rating_by_gross['gross']), score_mean), color='r')
plt.plot(rating_by_gross['gross'], np.full(len(rating_by_gross['gross']), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(rating_by_gross['gross'], np.full(len(rating_by_gross['gross']), score_mean+score_std), color='r', linestyle='dotted')
plt.xlim(5e+3, 5e+9)
plt.ylim(min_score,max_score)
plt.xlabel('Gross Profit')
plt.ylabel('IMDB Score')
plt.title('7a. Score Distribution by Gross Profit')

ax = fig.add_subplot(3, 2, 2)
plt.hist(films_per_gross['gross'], bins=logbins_gross)
plt.xscale('log')
plt.xlim(5e+3, 5e+9)
plt.xlabel('Gross Profit')
plt.ylabel('# of Films')
plt.title('7d. Distribution of Gross Profit')

ax = fig.add_subplot(3, 2, 3)
plt.semilogx(rating_by_budget['budget'], rating_by_budget['score'])
plt.plot(rating_by_gross['gross'], np.full(len(rating_by_gross['gross']), score_mean), color='r')
plt.plot(rating_by_gross['gross'], np.full(len(rating_by_gross['gross']), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(rating_by_gross['gross'], np.full(len(rating_by_gross['gross']), score_mean+score_std), color='r', linestyle='dotted')
plt.xlim(5e+3, 5e+9)
plt.ylim(min_score,max_score)
plt.xlabel('Budget')
plt.ylabel('IMDB Score')
plt.title('7b. Score Distribution by Budget')


ax = fig.add_subplot(3, 2, 4)
plt.hist(films_per_budget['budget'], bins=logbins_budget)
plt.xscale('log')
plt.xlim(5e+3, 5e+9)
plt.xlabel('Budget')
plt.ylabel('# of Films')
plt.title('7e. Distribution of Budget')

ax = fig.add_subplot(3, 2, 5)
plt.semilogx(rating_by_profitm['profit margin'], rating_by_profitm['score'])
plt.plot(rating_by_profitm['profit margin'], np.full(len(rating_by_profitm['profit margin']), score_mean), color='r')
plt.plot(rating_by_profitm['profit margin'], np.full(len(rating_by_profitm['profit margin']), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(rating_by_profitm['profit margin'], np.full(len(rating_by_profitm['profit margin']), score_mean+score_std), color='r', linestyle='dotted')
plt.xlim(1e-2, 1e+2)
plt.ylim(min_score,max_score)
plt.xlabel('Gross Profit/Budget')
plt.ylabel('IMDB Score')
plt.title('7c. Score Distribution by Gross Profit: Budget')

ax = fig.add_subplot(3, 2, 6)
plt.hist(films_per_profitm['profit margin'], bins=logbins_profitm)
plt.xscale('log')
plt.xlim(1e-2, 1e+2)
plt.xlabel('Gross Profit/Budget')
plt.ylabel('# of Films')
plt.title('7f. Distribution of Gross Profit: Budget')

plt.show()

# %% [markdown]
# These seem to have some variation and trends.

# %% [markdown]
# #### 8a. Distribution of Votes
# #### 8b. Score Distribution by Votes

# %%
rating_by_votes = df_train.loc[:,['votes','score']].groupby('votes').mean()
films_per_votes = df_train.loc[:,['votes']]

logbins_votes = np.logspace(np.log10(films_per_votes['votes'].min()),np.log10(films_per_votes['votes'].max()),bin_num)


fig = plt.figure()

fig.set_figwidth(10)
fig.set_figheight(7)

plt.subplots_adjust(wspace=0.4, hspace=0.4)


ax = fig.add_subplot(2, 1, 1)
plt.hist(films_per_votes['votes'], bins=logbins_votes)
plt.xscale('log')
plt.xlim(2e+2, 2e+6)
plt.xlabel('Votes')
plt.ylabel('# of Films')
plt.title('8a. Distribution of Votes')

ax = fig.add_subplot(2, 1, 2)
plt.semilogx(rating_by_votes)
plt.plot(films_per_votes['votes'], np.full(len(films_per_votes['votes']), score_mean), color='r')
plt.plot(films_per_votes['votes'], np.full(len(films_per_votes['votes']), score_mean-score_std), color='r', linestyle='dotted')
plt.plot(films_per_votes['votes'], np.full(len(films_per_votes['votes']), score_mean+score_std), color='r', linestyle='dotted')
plt.xlim(2e+2, 2e+6)
plt.ylim(min_score,max_score)
plt.xlabel('Votes')
plt.ylabel('IMDB Score')
plt.title('8b. Score Distribution by Votes')

plt.show()

# %% [markdown]
# Definite trends

# %% [markdown]
# ## SQL

# %%
df_SQL = df_movie

SQL_max = 32766
df_len = math.floor(SQL_max/df_SQL.shape[1])

df_SQL['index'] = df_SQL.index.values

df_SQL = df_SQL.sample(frac=1, random_state=1)

df_SQL = df_SQL.set_index(np.arange(0, df_SQL.shape[0], dtype=int))

df_SQL = df_SQL.truncate(after=df_len-1)
df_SQL = df_SQL.sort_values(by=['index'])
df_SQL = df_SQL.set_index(np.arange(0, df_SQL.shape[0], dtype=int))
df_SQL = df_SQL.drop('index', axis=1)

df_SQL.to_sql("MOVIE_DATA", con, if_exists='replace', index=False,method="multi")
# Out:
# 2047

# %%
df_SQL.loc[0:-1]
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, Month, score, votes, director, writer, star, country, budget, gross, company, runtime, profit margin]
# Index: []

# %%
# %sql select score from MOVIE_DATA order by "score" limit 1
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(1.9,)]

# %%
# %sql select count(score) from MOVIE_DATA where "score" = 6.5
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(88,)]

# %%
# %sql select COUNT(*),company from MOVIE_DATA group by company order by COUNT(*) desc
# Out:
#  * sqlite:///RealWorldData.db
# Done.
# [(143, 'Universal Pictures'),
#  (106, 'Warner Bros.'),
#  (105, 'Columbia Pictures'),
#  (99, 'Paramount Pictures'),
#  (90, 'Twentieth Century Fox'),
#  (60, 'New Line Cinema'),
#  (40, 'Walt Disney Pictures'),
#  (39, 'Touchstone Pictures'),
#  (32, 'Metro-Goldwyn-Mayer (MGM)'),
#  (30, 'TriStar Pictures'),
#  (29, 'Summit Entertainment'),
#  (28, 'Dreamworks Pictures'),
#  (27, 'Miramax'),
#  (26, 'Orion Pictures'),
#  (23, 'Fox Searchlight Pictures'),
#  (22, 'Lionsgate'),
#  (21, 'Dimension Films'),
#  (18, 'Fox 2000 Pictures'),
#  (18, 'Castle Rock Entertainment'),
#  (17, 'Screen Gems'),
#  (17, 'Revolution Studios'),
#  (13, 'New Regency Productions'),
#  (12, 'United Artists'),
#  (12, 'Alcon Entertainment'),
#  (11, 'DreamWorks Animation'),
#  (10, 'Focus Features'),
#  (9, 'Walt Disney Animation Studios'),
#  (9, 'Hollywood Pictures'),
#  (9, 'Dino De Laurentiis Company'),
#  (8, 'EuropaCorp'),
#  (8, 'De Laurentiis Entertainment Group (DEG)'),
#  (8, 'BBC Films'),
#  (7, 'Relativity Media'),
#  (7, 'Morgan Creek Entertainment'),
#  (6, 'Imagine Entertainment'),
#  (6, 'CBS Films'),
#  (6, 'Amblin Entertainment'),
#  (5, 'The Weinstein Company'),
#  (5, 'Pixar Animation Studios'),
#  (5, 'New World Pictures'),
#  (5, 'Millennium Films'),
#  (5, 'Lakeshore Entertainment'),
#  (5, 'Golan-Globus Productions'),
#  (5, 'Fox Atomic'),
#  (5, 'Eon Productions'),
#  (5, 'Carolco Pictures'),
#  (5, 'Caravan Pictures'),
#  (5, 'Beacon Communications'),
#  (5, 'BRON Studios'),
#  (4, 'Zentropa Entertainments'),
#  (4, 'Twentieth Century Fox Animation'),
#  (4, 'StudioCanal'),
#  (4, 'Rogue Pictures'),
#  (4, 'Polygram Filmed Entertainment'),
#  (4, 'PolyGram Filmed Entertainment'),
#  (4, 'Paramount Vantage'),
#  (4, 'Lions Gate Films'),
#  (4, 'Gold Circle Films'),
#  (4, 'Gaumont'),
#  (4, 'Empire Pictures'),
#  (4, 'Chernin Entertainment'),
#  (4, 'Blumhouse Productions'),
#  (4, 'Annapurna Pictures'),
#  (4, '3 Arts Entertainment'),
#  (3, 'Zoetrope Studios'),
#  (3, 'Worldview Entertainment'),
#  (3, 'Twisted Pictures'),
#  (3, 'Sony Pictures Animation'),
#  (3, 'Phoenix Pictures'),
#  (3, 'Participant'),
#  (3, 'Mandalay Entertainment'),
#  (3, 'Lorimar Film Entertainment'),
#  (3, 'Legendary Entertainment'),
#  (3, 'LD Entertainment'),
#  (3, 'Jack Rollins & Charles H. Joffe Productions'),
#  (3, 'Icon Entertainment International'),
#  (3, 'HBO Films'),
#  (3, 'Gravier Productions'),
#  (3, 'Gary Sanchez Productions'),
#  (3, 'Franchise Pictures'),
#  (3, 'Fine Line Features'),
#  (3, 'FilmDistrict'),
#  (3, 'Exclusive Media Group'),
#  (3, 'DreamWorks'),
#  (3, 'Constellation Entertainment'),
#  (3, 'Cinergi Pictures Entertainment'),
#  (3, 'Capella International'),
#  (3, 'Canal+'),
#  (3, 'British Broadcasting Corporation (BBC)'),
#  (3, 'Bold Films'),
#  (3, 'American Zoetrope'),
#  (3, 'Alliance Atlantis Communications'),
#  (3, 'A&M Films'),
#  (2, 'Working Title Films'),
#  (2, 'WingNut Films'),
#  (2, 'Weintraub Entertainment Group'),
#  (2, 'Warner Independent Pictures (WIP)'),
#  (2, 'Walt Disney Productions'),
#  (2, 'Voltage Pictures'),
#  (2, 'Vista Organization'),
#  (2, 'Vision PDG'),
#  (2, 'Turner Pictures (I)'),
#  (2, 'The Malpaso Company'),
#  (2, 'The Ladd Company'),
#  (2, 'The Cannon Group'),
#  (2, 'Silver Screen Partners IV'),
#  (2, 'Silver Screen Partners III'),
#  (2, 'Scott Rudin Productions'),
#  (2, 'Savoy Pictures'),
#  (2, 'Rysher Entertainment'),
#  (2, 'Robert Simonds Productions'),
#  (2, 'River Road Entertainment'),
#  (2, 'Recorded Picture Company (RPC)'),
#  (2, 'RKO Pictures'),
#  (2, 'R.P. Productions'),
#  (2, 'PolyGram Pictures'),
#  (2, 'Perfect World Pictures'),
#  (2, 'Pacific Western'),
#  (2, 'Outlaw Productions (I)'),
#  (2, 'Open Road Films (II)'),
#  (2, 'Night Life Inc.'),
#  (2, 'Mirage Enterprises'),
#  (2, 'Melvin Simon Productions'),
#  (2, 'Marvel Studios'),
#  (2, 'Marv Films'),
#  (2, 'Mandate Pictures'),
#  (2, 'Lucasfilm'),
#  (2, 'Live Entertainment'),
#  (2, 'Lightyear Entertainment'),
#  (2, 'Largo Entertainment'),
#  (2, 'LStar Capital'),
#  (2, 'Kramer & Sigman Films'),
#  (2, 'Kings Road Entertainment'),
#  (2, 'Kennedy Miller Productions'),
#  (2, 'Jasmine Productions Inc.'),
#  (2, 'Jackson/McHenry Company,The'),
#  (2, 'Insurge Pictures'),
#  (2, 'Illumination Entertainment'),
#  (2, 'IM Global'),
#  (2, 'IAC Films'),
#  (2, 'Hivemind'),
#  (2, 'Green Hat Films'),
#  (2, 'Great American Films Limited Partnership'),
#  (2, 'Gramercy Pictures (I)'),
#  (2, 'Good Universe'),
#  (2, 'Goldcrest Films International'),
#  (2, 'Geffen Pictures'),
#  (2, 'Fingerprint Releasing'),
#  (2, 'EMI Films'),
#  (2, 'Disney Television Animation'),
#  (2, 'Detour Filmproduction'),
#  (2, 'Destination Films'),
#  (2, 'DNA Films'),
#  (2, 'DJ Films'),
#  (2, 'Company Films'),
#  (2, 'Closest to the Hole Productions'),
#  (2, 'Cinetel Films'),
#  (2, 'Cinereach'),
#  (2, "Cinema '84"),
#  (2, 'Cinelou Films'),
#  (2, 'CiBy 2000'),
#  (2, 'Cannon Entertainment'),
#  (2, 'CJ Entertainment'),
#  (2, 'Brownstone Productions (II)'),
#  (2, 'Broken Road Productions'),
#  (2, 'Boll Kino Beteiligungs GmbH & Co. KG'),
#  (2, 'Bluegrass Films'),
#  (2, 'Blue Sky Studios'),
#  (2, 'Black Bear Pictures'),
#  (2, 'Bel Air Entertainment'),
#  (2, 'Barclays Mercantile Industrial Finance'),
#  (2, 'Bad Robot'),
#  (2, 'Avenue Pictures'),
#  (2, 'Atlantic Entertainment Group'),
#  (2, 'Artisan Entertainment'),
#  (2, 'Art Linson Productions'),
#  (2, 'ApolloMedia Distribution'),
#  (2, 'Anonymous Content'),
#  (2, 'Amercent Films'),
#  (2, 'Allied Filmmakers'),
#  (2, 'Alive Films'),
#  (2, 'Alcor Films'),
#  (2, 'A24'),
#  (2, '40 Acres & A Mule Filmworks'),
#  (2, '1492 Pictures'),
#  (1, 'thefyzz'),
#  (1, 'i am OTHER'),
#  (1, 'Zanuck/Brown Productions'),
#  (1, 'Yellow Bird'),
#  (1, 'Yari Film Group (YFG)'),
#  (1, 'World of Wonder Productions'),
#  (1, 'World Film Services'),
#  (1, 'Winwood Productions'),
#  (1, 'Winkler Films'),
#  (1, 'Wildgaze Films'),
#  (1, 'Wild Bunch'),
#  (1, 'Why Not Productions'),
#  (1, 'WhiteFlame Productions'),
#  (1, 'White Eagle'),
#  (1, 'Wayfare Entertainment'),
#  (1, 'Waverly Films'),
#  (1, 'Warner Bros. Pictures'),
#  (1, 'Warner Animation Group'),
#  (1, 'Walden Media'),
#  (1, 'Votiv Films'),
#  (1, 'Victoires International'),
#  (1, 'Vendian Entertainment'),
#  (1, 'Vegahom Europe'),
#  (1, 'Unplanned Movie'),
#  (1, 'Universal City Studios'),
#  (1, 'Unity Productions'),
#  (1, 'Ultra Muchos Productions'),
#  (1, 'USA Films'),
#  (1, 'Trésor Films'),
#  (1, 'Truth Entertainment (II)'),
#  (1, 'True West Films'),
#  (1, 'Treehouse Pictures'),
#  (1, 'Touchwood Pacific Partners 1'),
#  (1, 'Tomson Films'),
#  (1, 'Tomboy Films'),
#  (1, 'Toho Company'),
#  (1, 'Tim Burton Productions'),
#  (1, 'Thorn EMI Screen Entertainment'),
#  (1, 'This Is That Productions'),
#  (1, 'The Zanuck Company'),
#  (1, 'The Tyler Perry Company'),
#  (1, 'The Saul Zaentz Company'),
#  (1, 'The Safran Company'),
#  (1, 'The Rank Organisation'),
#  (1, 'The Movie Group'),
#  (1, 'The Mark Gordon Company'),
#  (1, 'The Last Picture Company'),
#  (1, 'The Halcyon Company'),
#  (1, 'Ternion Pictures'),
#  (1, 'Temple Hill Entertainment'),
#  (1, 'Tartan Productions'),
#  (1, 'Tapestry Films'),
#  (1, 'TaliaFilm II Productions'),
#  (1, 'Tag Entertainment'),
#  (1, 'TSG Entertainment'),
#  (1, 'TMS Entertainment'),
#  (1, 'Sycamore Pictures'),
#  (1, 'Sweetland Films'),
#  (1, 'Sunn Classic Pictures'),
#  (1, 'Sunbow Productions'),
#  (1, 'Studio Ghibli'),
#  (1, 'Studio 37'),
#  (1, 'Strong Heart/Demme Production'),
#  (1, 'Strike Entertainment'),
#  (1, 'Stoney Lake Entertainment'),
#  (1, 'Stage 6 Films'),
#  (1, 'SpectreVision'),
#  (1, 'Spectacle Entertainment Group'),
#  (1, 'Sparkle Roll Media'),
#  (1, 'Space Rocket Nation'),
#  (1, 'Sony Pictures Entertainment (SPE)'),
#  (1, 'Solana Films'),
#  (1, 'Slough Pond'),
#  (1, 'Siriol Productions'),
#  (1, 'Silver Sphere Corporation'),
#  (1, 'Shapiro-Glickenhaus Entertainment'),
#  (1, 'Shangri-La Entertainment'),
#  (1, 'SenArt Films'),
#  (1, 'See-Saw Films'),
#  (1, 'Sedic International'),
#  (1, 'Scott Free Productions'),
#  (1, 'Scion Films'),
#  (1, 'Sciarlò'),
#  (1, 'Sandollar Productions'),
#  (1, 'Samuelson Productions'),
#  (1, 'Samuels Media'),
#  (1, 'Samuel Goldwyn Films'),
#  (1, 'STX Films'),
#  (1, 'STX Entertainment'),
#  (1, 'Rumbalara Films'),
#  (1, 'Rogue'),
#  (1, 'Roadside Attractions'),
#  (1, 'Road Movies Filmproduktion'),
#  (1, 'River Road Productions'),
#  (1, 'Rimfire Films'),
#  (1, 'Rifkin-Eberts'),
#  (1, 'Rhombus Media'),
#  (1, 'Rent Productions LLC'),
#  (1, 'Renaissance Pictures'),
#  (1, 'Renaissance Films'),
#  (1, 'Religioso Primitiva'),
#  (1, 'Reel FX Creative Studios'),
#  (1, 'Red Hour Films'),
#  (1, 'Realitism Films'),
#  (1, 'RatPac-Dune Entertainment'),
#  (1, 'Rastar Films'),
#  (1, 'Rankin/Bass Productions'),
#  (1, 'Raindog Films'),
#  (1, 'Raffaella De Laurentiis Productions'),
#  (1, 'Pure Flix Productions'),
#  (1, 'Punch 21 Productions'),
#  (1, 'Pt. Merantau Films'),
#  (1, 'Producers Representative Organization'),
#  (1, 'Prime Film Productions LLC'),
#  (1, 'Primate Pictures'),
#  (1, 'Price Entertainment'),
#  (1, 'Pressman Productions'),
#  (1, 'Preferred Content'),
#  (1, 'Portman Entertainment Group'),
#  (1, 'Polyc International BV'),
#  (1, 'Point Grey Pictures'),
#  (1, 'Plan B Entertainment'),
#  (1, 'Pioneer LDC'),
#  (1, 'Picture Securities'),
#  (1, 'Phillips Whitehouse Productions'),
#  (1, 'Peters Entertainment'),
#  (1, 'Permut Presentations'),
#  (1, 'Penta Entertainment'),
#  (1, 'Pelican Productions LLC (I)'),
#  (1, 'Pathé Pictures International'),
#  (1, 'Partisan Productions'),
#  (1, 'Parkway Productions'),
#  (1, 'Paramount Players'),
#  (1, 'Paramount Animation'),
#  (1, 'Papazian-Hirsch Entertainment International'),
#  (1, 'Panorama Films'),
#  (1, 'Pandora Filmproduktion'),
#  (1, 'Pandora Cinema'),
#  (1, 'Pan Européenne'),
#  (1, 'PalmStar Media'),
#  (1, 'Palla'),
#  (1, 'Palace Pictures'),
#  (1, 'Overnight Films'),
#  (1, 'Overbrook Entertainment'),
#  (1, 'Open Road Films'),
#  (1, 'Open City Films'),
#  (1, 'Odeon Films'),
#  (1, 'O Entertainment'),
#  (1, 'Nova International Films'),
#  (1, 'No Frills Film Production'),
#  (1, 'Next Wave Films'),
#  (1, 'New Visions'),
#  (1, 'New Sky Communications Inc.'),
#  (1, 'New Horizons Picture'),
#  (1, 'Nelvana'),
#  (1, 'Nelson Entertainment'),
#  (1, 'Mutual Film Company'),
#  (1, 'Mundy Lane Entertainment'),
#  (1, 'Mulholland Productions'),
#  (1, 'Mosaic'),
#  (1, 'Morra, Brezner, Steinberg and Tenenbaum Entertainment (MBST)'),
#  (1, 'Monsterfoot Productions'),
#  (1, 'Mod Producciones'),
#  (1, 'Merchant Ivory Productions'),
#  (1, 'Marvel Enterprises'),
#  (1, 'Marked Entertainment'),
#  (1, 'Marcy Media'),
#  (1, 'Mandalay Vision'),
#  (1, 'Mandalay Pictures'),
#  (1, 'Malpaso Productions'),
#  (1, 'Maljack Productions'),
#  (1, 'Majestic Films International'),
#  (1, 'Magnolia Pictures'),
#  (1, 'Magic Light Pictures'),
#  (1, 'Mace Neufeld Productions'),
#  (1, 'Macari/Edelstein'),
#  (1, 'MDP Worldwide'),
#  (1, 'Légende Films'),
#  (1, 'Lynda Obst Productions'),
#  (1, 'Lumiere Pictures'),
#  (1, 'Lucille Ball Productions'),
#  (1, 'Lucamar Productions'),
#  (1, 'Lost Soul Productions'),
#  (1, 'Lorimar Productions'),
#  (1, 'Little Tokyo Productions'),
#  (1, 'Likely Story'),
#  (1, 'Lightning Pictures'),
#  (1, 'Lewitt / Eberts Productions'),
#  (1, 'Levins-Henenlotter'),
#  (1, 'Les Films 21'),
#  (1, 'Les Armateurs'),
#  (1, 'Leisure Investment Company'),
#  (1, 'Legend3D'),
#  (1, 'Lawrence Gordon Productions'),
#  (1, 'Lava Bear Films'),
#  (1, 'Laurenfilm'),
#  (1, 'Laurence Mark Productions'),
#  (1, 'Largo International N.V.'),
#  (1, 'Lancaster Gate'),
#  (1, 'La Petite Reine'),
#  (1, 'L.A. Films'),
#  (1, 'Kuzui Enterprises'),
#  (1, 'Kouf/Bigelow Productions'),
#  (1, 'Kingsgate Films'),
#  (1, 'Killer Films'),
#  (1, 'Keep Your Head'),
#  (1, 'Kanun parvaresh fekri'),
#  (1, 'Juno Pix'),
#  (1, 'Josephson Entertainment'),
#  (1, 'Joseph S. Vecchio Entertainment'),
#  (1, 'Jim Henson Pictures'),
#  (1, 'Jet Tone Production'),
#  (1, 'Jersey Films'),
#  (1, 'Jerry Bruckheimer Films'),
#  (1, 'Jay Weston Productions'),
#  (1, 'James Glickenhaus'),
#  (1, 'Jaffe-Lansing'),
#  (1, 'JVC Entertainment Networks'),
#  (1, 'JLT Productions'),
#  (1, "It's a Laugh Productions"),
#  (1, 'Ironbark Films'),
#  (1, 'Initial Entertainment Group (IEG)'),
#  (1, 'Indian Paintbrush'),
#  (1, 'Independent Pictures (II)'),
#  (1, 'Independent Film Centre'),
#  (1, 'Incentive Filmed Entertainment'),
#  (1, 'Imperative Entertainment'),
#  (1, 'Image Organization'),
#  (1, 'Iconoclast'),
#  (1, 'IPC Films'),
#  (1, 'IFC Productions'),
#  (1, 'Hydraulx'),
#  (1, 'Hyde Park Entertainment'),
#  (1, 'Hunter Killer Productions'),
#  (1, 'Human Stew Factory'),
#  (1, 'Hughes Entertainment'),
#  (1, 'Huayi Brothers Media'),
#  (1, 'Huayi Brothers'),
#  (1, 'House Row Productions'),
#  (1, 'Hopscotch Features'),
#  (1, 'Hill/Rosenman'),
#  (1, 'High School Sweethearts'),
#  (1, 'High Bar Productions'),
#  (1, 'Heyday Films'),
#  (1, 'Hero Entertainment'),
#  (1, 'Henson Associates (HA)'),
#  (1, 'Hemdale'),
#  (1, "Hell's Kitchen Films"),
#  (1, 'Haxan Films'),
#  (1, 'Haut et Court'),
#  (1, 'Hasbro'),
#  (1, 'Hart Sharp Entertainment'),
#  (1, 'Harold Robbins International Company'),
#  (1, 'Happy Madison Productions'),
#  (1, 'HanWay Films'),
#  (1, 'Hammerhead Productions'),
#  (1, 'Halloween VI Productions'),
#  (1, 'Hal Roach Studios'),
#  (1, 'HK Film Corporation'),
#  (1, 'HDNet Films'),
#  (1, 'HBO Pictures'),
#  (1, 'Gullane Pictures'),
#  (1, 'Gulfstream Pictures'),
#  (1, 'Greenwich Film Productions'),
#  (1, 'Greenleaf Productions'),
#  (1, 'Green/Renzi'),
#  (1, 'Greater Productions'),
#  (1, 'Gracie Films'),
#  (1, 'Gotham Group'),
#  (1, 'Goodspeed Productions'),
#  (1, 'Good Machine'),
#  (1, 'Golden Harvest Company'),
#  (1, 'GoldDay'),
#  (1, 'Golar Productions'),
#  (1, 'Goalpost Pictures'),
#  (1, 'Ghoulardi Film Company'),
#  (1, 'Ghost House Pictures'),
#  (1, 'Georgetown Productions Inc.'),
#  (1, 'Genre Films'),
#  (1, 'Gail Katz Productions'),
#  (1, 'GK Films'),
#  (1, 'G-BASE'),
#  (1, 'Funny Boy Films'),
#  (1, 'Fuller Films'),
#  (1, 'Fuego Films'),
#  (1, 'Front Films'),
#  (1, 'Freddie Fields Productions'),
#  (1, 'Fox Run Productions Inc.'),
#  (1, 'Four Seasons Partnership'),
#  (1, 'FortyFour Studios'),
#  (1, 'Forge'),
#  (1, 'Flying Heart Films'),
#  (1, 'Flashlight Films'),
#  (1, 'Flan de Coco Films'),
#  (1, 'First Look International'),
#  (1, 'Filmways Pictures'),
#  (1, 'Filmline Productions'),
#  (1, 'Filmax Group'),
#  (1, 'Filmax'),
#  (1, 'FilmNation Entertainment'),
#  (1, 'Film4'),
#  (1, 'Film Workshop'),
#  (1, 'Film Partner International'),
#  (1, 'Film 44'),
#  (1, 'Field Guide Films'),
#  (1, 'Fewlas Entertainment'),
#  (1, 'Fallingcloud'),
#  (1, 'Fairview Entertainment'),
#  (1, 'FX Sound'),
#  (1, 'FTM Productions'),
#  (1, 'Evolution Entertainment'),
#  (1, 'Everyman Pictures'),
#  (1, 'Evenstar Films'),
#  (1, 'Eureka Pictures'),
#  (1, 'Estudios Picasso'),
#  (1, 'Estudios Churubusco Azteca S.A.'),
#  (1, 'Esperanza Films Inc.'),
#  (1, 'Escape Artists'),
#  (1, 'Eros Worldwide'),
#  (1, 'Epsilon Motion Pictures'),
#  (1, 'Entertainment Manufacturing Company'),
#  (1, 'Enigma Productions'),
#  (1, 'Englander Productions'),
#  (1, 'Endgame Entertainment'),
#  (1, 'Enderby Entertainment'),
#  (1, 'Encino Man Productions'),
#  (1, 'Enchantment Films Inc.'),
#  (1, 'Emphatic Films'),
#  (1, 'Emmett/Furla/Oasis Films (EFO Films)'),
#  (1, 'Embassy Pictures'),
#  (1, 'Elysian Dreams'),
#  (1, 'Elle Driver'),
#  (1, 'Eleventh Street Production'),
#  (1, 'Electric City Entertainment'),
#  (1, 'Elara Pictures'),
#  (1, 'El Camino Pictures'),
#  (1, 'Efer Productions'),
#  (1, 'Eddie Murphy Productions'),
#  (1, 'Eclectic Pictures'),
#  (1, 'Echo Lake Entertainment'),
#  (1, 'Eagle Associates.'),
#  (1, 'ETIC Films'),
#  (1, 'ERBP'),
#  (1, 'EFTI'),
#  (1, 'Dune Entertainment III'),
#  (1, 'Dune Entertainment'),
#  (1, 'Dovemead Films'),
#  (1, 'Double Play'),
#  (1, 'Double Feature Films'),
#  (1, 'Double Dare You (DDY)'),
#  (1, 'Dorset Productions'),
#  (1, 'Don Simpson/Jerry Bruckheimer Films'),
#  (1, 'Disneytoon Studios'),
#  (1, 'Digital Image Associates'),
#  (1, 'DiNovi Pictures'),
#  (1, 'Dharma Productions'),
#  (1, 'Devoted Productions'),
#  (1, 'Depth of Field'),
#  (1, 'Delphi III Productions'),
#  (1, 'Deerjen Films'),
#  (1, 'Decibel Films'),
#  (1, 'De Line Pictures'),
#  (1, 'De Fina-Cappa'),
#  (1, 'Dayday Films'),
#  (1, 'Davros Films'),
#  (1, 'Davis-Panzer Productions'),
#  (1, 'Davis-Films'),
#  (1, 'Davis Entertainment'),
#  (1, 'David Kirschner Productions'),
#  (1, 'Danjaq'),
#  (1, 'Crunk Pictures'),
#  (1, 'Cruise/Wagner Productions'),
#  (1, 'Crowvision Inc.'),
#  (1, 'Cristaldifilm'),
#  (1, 'Crescent Drive Pictures'),
#  (1, 'Cre Film'),
#  (1, 'Cradle Productions Inc.'),
#  (1, 'Constellation'),
#  (1, 'Constantin Film International'),
#  (1, 'Constantin Film'),
#  (1, 'Color Force'),
#  (1, 'Colgems Productions Ltd.'),
#  (1, 'Cobalt Media Group'),
#  (1, 'Clinica Estetico'),
#  (1, 'Cliffjack Motion Pictures'),
#  (1, 'City Films'),
#  (1, 'Circle Films'),
#  (1, 'Cineville'),
#  (1, 'Cinerenta Medienbeteiligungs KG'),
#  (1, 'Cineplex Odeon Films'),
#  (1, 'Cinematograph AB'),
#  (1, 'Cinema Line Film Corporation'),
#  (1, 'Cinema Group Ventures'),
#  (1, 'Cinecorp SAC'),
#  (1, 'Chockstone Pictures'),
#  (1, 'Chiodo Brothers Productions'),
#  (1, 'China Film Group Corporation (CFGC)'),
#  (1, 'Cherry Sky Films'),
#  (1, 'Chartoff-Winkler Productions'),
#  (1, 'Charles Burnett Productions'),
#  (1, 'Channel Four Films'),
#  (1, 'Challenge Film Corporation'),
#  (1, 'Centurion'),
#  (1, 'Centropolis Film Productions'),
#  (1, 'Celluloid Dreams'),
#  (1, 'Celandine Films'),
#  (1, 'Celador Films'),
#  (1, 'Cecchi Gori Pictures'),
#  (1, 'Cecchi Gori Group Tiger Cinematografica'),
#  (1, 'Caviar'),
#  (1, 'Casey Silver Productions'),
#  (1, 'Capricorn'),
#  (1, 'Cappa Production'),
#  (1, 'Capitol Films'),
#  (1, 'Capcom Entertainment'),
#  (1, 'Canon Italia S.r.l.'),
#  (1, 'Cannon Group'),
#  (1, 'Cannon Films Inc.'),
#  (1, 'Cannon Films'),
#  (1, 'Candyman Films'),
#  (1, 'CalMaple'),
#  (1, 'Cabal Film'),
#  (1, 'CTB Film Company'),
#  (1, 'CG Cinéma'),
#  (1, 'C.A.T. Films'),
#  (1, 'C-2 Pictures'),
#  (1, 'C & C Brown Production'),
#  (1, 'Bullwinkle Studios'),
#  (1, 'Bruin Grip Services'),
#  (1, 'Brooksfilms'),
#  (1, 'Bronco Productions'),
#  (1, 'Broadway Video'),
#  (1, 'Broadway Pictures'),
#  (1, 'Broad Green Pictures'),
#  (1, 'British Broadcasting Corporation (BBC) Television'),
#  (1, 'Brillstein-Grey Entertainment'),
#  (1, 'Breathless Associates'),
#  (1, 'Braven Films'),
#  (1, 'Boies / Schiller Film Group'),
#  (1, 'Blueprint Pictures'),
#  (1, 'Blue Train Productions'),
#  (1, 'Blue Streak Films'),
#  (1, 'Blue Sky Films'),
#  (1, 'Blue Askew'),
#  (1, 'Block 2 Pictures'),
#  (1, 'Bleiberg Entertainment'),
#  (1, 'Blank of the Dead Productions'),
#  (1, 'Bill Graham Films'),
#  (1, 'Big Talk Productions'),
#  (1, 'Beverly Detroit'),
#  (1, 'BenderSpink'),
#  (1, 'Belladonna Productions'),
#  (1, 'Before The Door Pictures'),
#  (1, 'Beco Films'),
#  (1, 'Bazmark Films'),
#  (1, 'Bavaria Film'),
#  (1, 'Bates Entertainment'),
#  (1, 'Baltimore Pictures'),
#  (1, 'Balcor Film Investors'),
#  (1, 'Bad Lt. Productions'),
#  (1, 'Bad Cop Bad Cop Film Productions'),
#  (1, 'Babylon'),
#  (1, 'BZ Entertainment'),
#  (1, 'BBL Motion Picture Studios'),
#  (1, 'Azoff Entertainment'),
#  (1, 'Awesomeness Films'),
#  (1, 'Award Entertainment'),
#  (1, 'Automatik Entertainment'),
#  (1, 'August Entertainment'),
#  (1, 'Audiovisual Development Bureau, Ministerio da Cultura'),
#  (1, 'Audiovisual Aval SGR'),
#  (1, 'Audax Films'),
#  (1, 'Atlas Entertainment'),
#  (1, 'Atlantic Pictures (II)'),
#  (1, 'Astral Bellevue Pathé'),
#  (1, 'Asia Union Film & Entertainment Ltd.'),
#  (1, 'Asghar Farhadi Productions'),
#  (1, 'Ascot Film'),
#  (1, 'Artists Public Domain'),
#  (1, 'Artfire Films'),
#  (1, 'Arnold Kopelson Productions'),
#  (1, 'Armory Films'),
#  (1, 'Aries Cinematográfica Argentina'),
#  (1, 'ArieScope Pictures'),
#  (1, 'Arcade Pictures'),
#  (1, 'Apostle'),
#  (1, 'Apatow Productions'),
#  (1, 'Annapurna Productions'),
#  (1, 'Animal Kingdom'),
#  (1, "Anarchist's Convention Films"),
#  (1, 'American Playhouse'),
#  (1, 'American Filmworks'),
#  (1, 'Ambridge Film Partnership'),
#  (1, 'Amasia Entertainment'),
#  (1, 'Am Psycho Productions'),
#  (1, 'Allspark Pictures'),
#  (1, 'Alloy Entertainment'),
#  (1, 'Allison Shearmur Productions'),
#  (1, 'All Net Productions'),
#  (1, 'All Girl Productions'),
#  (1, 'After Dark Films'),
#  (1, 'Adventure Pictures'),
#  (1, 'Adams Apple Film Company'),
#  (1, 'Ada Films'),
#  (1, 'Access Entertainment'),
#  (1, 'Abraham Productions'),
#  (1, 'Aaron Spelling Productions'),
#  (1, 'Aaron Russo Entertainment'),
#  (1, 'Aardman Animations'),
#  (1, 'AVCO Embassy Pictures'),
#  (1, 'ASIG Productions'),
#  (1, 'AR Films'),
#  (1, 'AMLF'),
#  (1, 'AM/PM Entertainment'),
#  (1, 'AITD Productions'),
#  (1, 'ABC Motion Pictures'),
#  (1, 'A Band Apart'),
#  (1, '7 Films Cinéma'),
#  (1, '3 Miles Apart Productions Ltd.'),
#  (1, '2DUX²'),
#  (1, '21st Century Films'),
#  (1, '20th Century Studios'),
#  (1, '2.0 Entertainment'),
#  (1, '19 Entertainment'),
#  (1, '.406 Production')]

# %% [markdown]
# ## Model building

# %%
def graph(w, predictions, y_test_set, rate_std, range_min, range_max):
    """
    This creates standardized graphs to analyze the machine learning models we used.
    
    w - The width of the bars used in the bar graphs
    predictions - The set of scores predicted by the model from the test data
    y_test_set - The correct scores of the test data
    """
    x = np.arange(0,len(predictions))
    #w = w

    fig = plt.figure()
    
    fig.set_figwidth(10)
    fig.set_figheight(8)

    ax = fig.add_subplot(3, 1, 1)
    ax.bar(x-w/2, y_test_set, width=w, color='b', align='center')
    ax.bar(x+w/2, predictions, width=w, color='r', align='center')
    plt.xlim(range_min,range_max)


    ax = fig.add_subplot(3, 1, 2)
    ax.bar(x, y_test_set - predictions, width=w, color='b', align='center')
    plt.xlim(range_min,range_max)

    ax = fig.add_subplot(3, 1, 3)
    ax.bar(x, abs(y_test_set - predictions), width=w, color='b', align='center')
    ax.plot(x, np.full(len(x), rate_std), color='r')
    plt.xlim(range_min,range_max)
    plt.show()
    
    
def Metric_Report(predictions, y_test_set):
    """
    This creates a table of some useful statistics to evaluate our models.
    
    predictions - The set of scores predicted by the model from the test data
    y_test_set - The correct scores of the test data
    """
    NMAE = np.mean(np.absolute(predictions - y_test_set))/(max(y_test_set)-min(y_test_set)) # Normalized Mean Absolute Error
    NRMSE = np.sqrt(np.mean((predictions - y_test_set) ** 2))/(max(y_test_set)-min(y_test_set)) # Normalized Root Mean Squared Error
    R2 = r2_score(y_test_set, predictions) # R squared value
    return pd.DataFrame([{'NMAE':NMAE, 'NRMSE':NRMSE, 'R2':R2}])

# %%
df_train.loc[:-1]
# Out:
# Empty DataFrame
# Columns: [name, G, NC-17, Not Rated, PG, PG-13, R, Unrated, Action, Adventure, Animation, Biography, Comedy, Crime, Drama, Fantasy, Horror, Mystery, year, Month, score, votes, budget, gross, runtime, Country Codes]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# When deciding which parameters to keep in the model, I trained the model with different parameters used. Exculding some and leaving in other changed the NRMSE and R^2 values only slightly, with some favoring NRMSE and vice versa. Ultimately I favored making the NMRSE as low as possible which meant leave in all the parameters except the title.

# %%
features = df_train.drop(columns=['name', 'score'], axis=1)

Y = pd.to_numeric(df_train['score']*10, downcast='integer')

# %%
x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size=0.3, random_state=10)

# %%
rating_std = np.std(Y)

# %% [markdown]
# ### Models
#
# We will evaluate some models to see which is best to use. We will determine this based on R^2, NMAE and NMSE.

# %%
LinearReg = linear_model.LinearRegression()
LinearReg.fit(x_train, y_train)
predictionsLR = LinearReg.predict(x_test)
Metric_Report(predictionsLR, y_test)
# Out:
#        NMAE     NRMSE        R2
# 0  0.076321  0.104866  0.373567

# %%
RidgeReg = linear_model.Ridge(alpha=22)
RidgeReg.fit(x_train, y_train)
predictionsRR = RidgeReg.predict(x_test)
Metric_Report(predictionsRR, y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.40805e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#       NMAE     NRMSE        R2
# 0  0.07632  0.104868  0.373552

# %%
LassoReg = linear_model.Lasso(alpha=0.011)
LassoReg.fit(x_train, y_train)
predictionsLaR = LassoReg.predict(x_test)
Metric_Report(predictionsLaR, y_test)
# Out:
#       NMAE     NRMSE        R2
# 0  0.07635  0.104927  0.372843

# %%
BayesReg = linear_model.BayesianRidge()
BayesReg.fit(x_train, y_train)
predictionsBR = BayesReg.predict(x_test)
Metric_Report(predictionsBR, y_test)
# Out:
#        NMAE     NRMSE        R2
# 0  0.076301  0.104837  0.373915

# %%
Tree = DecisionTreeRegressor(max_depth=6)
Tree.fit(x_train,y_train)
predictionsDT = Tree.predict(x_test)
Metric_Report(predictionsDT, y_test)
# Out:
#        NMAE    NRMSE        R2
# 0  0.073954  0.10061  0.423388

# %%
KNNR = KNeighborsRegressor(n_neighbors=82)
KNNR.fit(x_train,y_train)
predictionsKNNR = KNNR.predict(x_test)
Metric_Report(predictionsKNNR, y_test)
# Out:
#        NMAE     NRMSE        R2
# 0  0.096843  0.125862  0.097609

# %%
Svr = SVR(kernel="rbf")
Svr.fit(x_train,y_train)
predictionsSvr = Svr.predict(x_test)
Metric_Report(predictionsSvr, y_test)
# Out:
#        NMAE     NRMSE        R2
# 0  0.096608  0.126886  0.082871

# %% [markdown]
# It seems the regression tree is best. We will plot the predictions and residuals.

# %%
graph(0.3, predictionsDT, y_test, rating_std, 0, 100)
